# %% [markdown]
# # 04_Exercise

# %% [markdown]
# ### (Q1)
# <p></p>
# <font color=brown>
# Write a function that takes as input a list defined by [i for i in range(1,101)]
# and returns
# <li>dictionary with Key as element of list and Value as square of it</li>
# <li>count of even numbers</li>
# <li>count of odd numbers</li>
# <p></p>
#
# </font>

# %% [markdown]
# ### (Q2)
# <p></p>
# <font color=brown>
# Using map(), given an iterable of range(0,100), output a dictionary with two key:value pairs
# <li>{'Even':[List of all even numbers]}</li>
# <li>{'Odd':[List of all odd numbers]}</li>
# <p></p>
#
# </font>
